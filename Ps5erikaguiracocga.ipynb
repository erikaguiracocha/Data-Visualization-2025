# %% [markdown]
# <a href="https://colab.research.google.com/github/erikaguiracocha/Data-Visualization-2025/blob/main/Ps5erikaguiracocga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PS 5** **Story**

# %% [markdown]
# **PS 5**
#
# 1. build on ps4 (see ps4 instructions again): fix it up and beef it up
# 2. may use some of the bonus libs like plotly, html/website hosting; but better have solid story just with mpl than fancy meaningless
# stuff; again: idea and story matter most and simplicity first
# 3. now it’s the time to take a step back and think hard about your vis: what it all means, what’s the story there, give a lot of
# thought to interpretations, be critical; and also circle back to initial research questions and hypothesis–found evidence in support
# or against? strong evidence or weak? and maybe conditional? say yes for female, but no for males, etc
# 4. list problems/limitations: do have a section on limitatations/future res

# %% [markdown]
# **Dataset Overview and Research Focus**
#
# This study examines data from 21 counties in New Jersey between 2020 and 2022 to explore how local crime rates influence police budget allocation. By analyzing reported crimes, budgetary figures, and socioeconomic indicators—such as population and unemployment rates—this research aims to uncover patterns in how counties prioritize public safety spending in response to varying crime levels.
#
# **Research Story:** Why This Matters The relationship between crime and police funding is a central topic in public policy, especially in times of economic uncertainty and shifting public perceptions of law enforcement. During the years 2020 to 2022, counties across New Jersey faced challenges brought on by the COVID-19 pandemic, including economic disruptions, rising unemployment, and changes in public safety needs.
#
# This period presents a unique opportunity to study how counties adjusted their police budgets in response to crime trends and socioeconomic pressures. By investigating this relationship, we can better understand how local governments allocate resources in times of crisis and whether their responses align with actual public safety needs.
#
# **Research Question**
#
# How do crime rates in New Jersey counties influence police budget allocation?
#
# **Hypothesis:** I hypothesize that counties with higher crime rates allocate a larger proportion of their budgets to the police, as they require more resources to address increased demand for law enforcement services.
#
# **Key Variables**
#
# Crime Data: Total number of reported crimes per county per year (2020–2022), indicating crime levels.
#
# Police Budget: Total annual police department allocation per county.
#
# County: Name of the 21 New Jersey counties included in the analysis.
#
# Year: The time dimension, capturing data from 2020, 2021, and 2022.
#
# Population: Estimated population per county, to provide context for per capita analysis.
#
# Unemployment Rate: Annual unemployment rate per county, used to explore potential socioeconomic influences on crime and budget decisions.
#
# **Data Sources**
#
# Crime Data: New Jersey Department of Law and Public Safety.
#
# Police Budget Data: Annual reports from the New Jersey Division of Local Government Services.
#
# Socioeconomic Data: Population and unemployment rates from the New Jersey Department of Labor and Workforce Development.
#
# Data Justification The integration of crime statistics, police funding data, and socioeconomic indicators enables a comprehensive analysis of how counties respond to public safety needs. Population and unemployment data provide necessary context to interpret variations in crime and budgeting patterns, while the three-year timeframe allows for the identification of temporal trends and policy shifts in response to evolving local conditions.
#
# **Map of New Jersey by County**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Uploaded Data**

# %%
import pandas as pd  #original crime data uploaded
url_crime_data = 'https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/crime%20by%20county%20New%20Jersey.csv'
crime_data = pd.read_csv(url_crime_data, header=1)
print("Original Crime Data:")
print(crime_data.head(30))  # Show 21 counties
# Out:
# Original Crime Data:
#               County     2020     2021       2022
# 0          Atlantic    46,551   42,324     47,072
# 1            Bergen   193,882  208,751    294,129
# 2        Burlington    44,940   48,929     52,173
# 3             Camden  103,373  114,926    194,754
# 4          Cape May    64,234   65,174     56,205
# 5        Cumberland    17,378   14,656     17,993
# 6              Essex   45,882   47,082     56,433
# 7        Gloucester    38,332   35,690     40,038
# 8            Hudson    32,374   29,689     38,604
# 9         Hunterdon     8,036    7,447     10,467
# 10           Mercer    21,976   21,813     26,797
# 11        Middlesex    36,204   35,448     45,162
# 12         Monmouth    85,417   70,450     76,941
# 13           Morris    33,417   26,142     31,456
# 14            Ocean    55,640   39,291     52,245
# 15          Passaic    28,610   27,683     34,688
# 16            Salem    19,312   15,548     14,772
# 17         Somerset    21,493   21,174     22,982
# 18           Sussex     6,345    7,471      7,074
# 19            Union    35,176   35,881     41,550
# 20            Warren   20,030   19,753     17,675
# 21  Total New Jersey  958,604  935,321  1,133,384

# %%
# URL of the CSV file
url_budget_data = 'https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/police%20budgets%20in%20New%20Jersey.csv'

# Try to read the file
try:
    # If the second row is the header, use header=1
    budget_data = pd.read_csv(url_budget_data, header=1)
    print("Original Budget Data:")
    print(budget_data.head(30))  # Display the first 30 rows

except Exception as e:
    print(f"There was an error loading the file: {e}")
# Out:
# Original Budget Data:
#               County              2020              2021              2022
# 0          Atlantic     119,262,425.86    117,407,829.60    123,993,860.75
# 1            Bergen     427,518,344.81    448,124,550.75    471,782,982.68
# 2        Burlington     122,407,763.95    125,868,638.98    128,190,733.44
# 3            Camden     137,420,012.72    135,626,159.37    147,391,782.25
# 4          Cape May      48,629,849.27     52,207,062.40     54,103,285.95
# 5        Cumberland      35,045,613.87     36,259,361.36     37,329,195.20
# 6             Essex     350,382,509.60    464,878,127.99    381,983,364.75
# 7        Gloucester      67,519,873.43     65,845,717.39     79,816,171.41
# 8            Hudson     290,272,331.25    300,219,111.87    377,519,753.78
# 9         Hunterdon      28,100,764.97     29,438,131.72     31,540,757.26
# 10           Mercer      93,981,950.66    104,382,301.52     97,266,160.77
# 11        Middlesex     253,427,739.92    292,934,332.15    331,800,018.84
# 12         Monmouth     261,784,930.78    271,539,409.48    282,625,410.02
# 13           Morris     171,635,578.16    184,152,262.87    195,233,806.17
# 14            Ocean     224,440,512.53    228,994,762.61    231,442,122.59
# 15          Passaic     101,872,259.28    148,684,341.76    197,295,052.89
# 16            Salem       9,149,236.34     15,079,410.98     13,660,155.37
# 17         Somerset     100,180,014.14     60,327,888.26    117,789,364.83
# 18           Sussex      33,385,136.64     29,710,261.77     33,563,129.27
# 19            Union     186,982,367.17    224,208,846.59    246,829,591.40
# 20           Warren      26,138,557.21     26,936,297.87     29,352,144.76
# 21  Total New Jersey  3,089,537,772.56  3,362,824,807.29  3,610,508,844.38

# %%
# Load the population data
url_population_data = 'https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/population%20by%20county.csv'
population_data = pd.read_csv(url_population_data)

print("Original Population Data:")
print(population_data.head(30))  # Display the first 30 rows to check the structure
# Out:
# Original Population Data:
#          County    2,020    2,021    2,022
# 0     Atlantic   274,190  274,956  275,382
# 1        Bergen  953,690  955,383  953,540
# 2   Burlington   461,682  464,479  466,101
# 3       Camden   523,122  524,093  524,649
# 4     Cape May    95,044   95,706   95,405
# 5   Cumberland   153,719  152,083  151,347
# 6        Essex   859,974  854,233  849,724
# 7    Gloucester  302,563  304,592  306,767
# 8       Hudson   721,879  703,448  702,381
# 9    Hunterdon   128,786  129,671  129,805
# 10      Mercer   386,466  382,172  380,779
# 11   Middlesex   861,408  862,364  861,094
# 12    Monmouth   642,836  646,517  644,228
# 13      Morris   508,439  510,613  511,219
# 14       Ocean   638,465  649,825  655,663
# 15      Passaic  523,439  518,376  513,634
# 16       Salem    64,841   65,045   65,157
# 17     Somerset  344,754  346,498  347,047
# 18      Sussex   143,915  145,721  145,575
# 19       Union   573,660  572,833  570,417
# 20      Warren   109,520  110,567  110,903

# %%
# Load the unemployment rate data from the URL
url = 'https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/unemployment%20rate%20by%20county.csv'
unemployment_data = pd.read_csv(url)

# Display the column names to confirm the structure
print("Column Names:")
print(unemployment_data.columns)

# Display the first few rows to check the data
print("\nFirst Few Rows of the Dataset:")
print(unemployment_data.head())

# Filter the dataset for the years 2020 to 2022 and display it
unemployment_data_filtered = unemployment_data[['County', '2020', '2021', '2022']]
print("\nFiltered Data (County and Years 2020-2022):")
print(unemployment_data_filtered)
# Out:
# Column Names:
# Index(['County', '2020', '2021', '2022'], dtype='object')
#
# First Few Rows of the Dataset:
#         County  2020  2021  2022
# 0    Atlantic   17.1   9.9   5.4
# 1       Bergen   9.2   6.3   3.5
# 2  Burlington    7.9   5.7   3.5
# 3      Camden    9.7   7.1   4.2
# 4    Cape May   13.7   9.3   6.8
#
# Filtered Data (County and Years 2020-2022):
#          County  2020  2021  2022
# 0     Atlantic   17.1   9.9   5.4
# 1        Bergen   9.2   6.3   3.5
# 2   Burlington    7.9   5.7   3.5
# 3       Camden    9.7   7.1   4.2
# 4     Cape May   13.7   9.3   6.8
# 5   Cumberland   10.4   8.1   5.3
# 6        Essex   11.2   8.3   4.7
# 7    Gloucester   8.9   6.4   3.8
# 8       Hudson   10.2   7.1   3.8
# 9    Hunterdon    6.9   4.9   3.0
# 10      Mercer    7.2   5.5   3.3
# 11   Middlesex    8.5   6.1   3.5
# 12    Monmouth    8.5   5.9   3.5
# 13      Morris    7.5   5.3   3.2
# 14       Ocean    9.1   6.3   3.9
# 15      Passaic  12.1   8.7   4.8
# 16       Salem    9.2   7.7   4.8
# 17     Somerset   7.5   5.4   3.2
# 18      Sussex    9.0   6.3   3.9
# 19       Union    9.5   7.0   4.0
# 20      Warren    8.2   5.9   3.6

# %% [markdown]
# #**Scatter plot - Average Crime vs Average Budgets 2020 - 2022 - New Jersey**

# %%
import matplotlib.pyplot as plt

# Load data
crime_df = pd.read_csv(url_crime_data, header=1)
budget_df = pd.read_csv(url_budget_data, header=1)

# Remove "Total New Jersey" row
crime_df = crime_df[crime_df['County'] != 'Total New Jersey']
budget_df = budget_df[budget_df['County'] != 'Total New Jersey']

# Remove commas and convert to numeric
for year in ['2020', '2021', '2022']:
    crime_df[year] = crime_df[year].replace({',': ''}, regex=True).astype(float)
    budget_df[year] = budget_df[year].replace({',': '', '\$': ''}, regex=True).astype(float)

# Calculate averages
crime_df['Average_Crime'] = crime_df[['2020', '2021', '2022']].mean(axis=1)
budget_df['Average_Budget'] = budget_df[['2020', '2021', '2022']].mean(axis=1)

# Merge datasets
merged_df = pd.merge(crime_df[['County', 'Average_Crime']],
                     budget_df[['County', 'Average_Budget']],
                     on='County')

# Plot
plt.figure(figsize=(14, 8))
plt.scatter(merged_df['Average_Crime'], merged_df['Average_Budget'],
            color='teal', edgecolor='black', s=100)

# Add labels (county names)
for _, row in merged_df.iterrows():
    plt.text(row['Average_Crime'], row['Average_Budget'], row['County'],
             fontsize=8, ha='center', va='center', color='white',
             bbox=dict(facecolor='black', alpha=0.6, boxstyle='round,pad=0.2'))

# Axis labels and title
plt.title('Average Crime vs. Average Police Budget (2020–2022) - New Jersey Counties', fontsize=16)
plt.xlabel('Average Crime Count (2020–2022)', fontsize=12)
plt.ylabel('Average Police Budget (USD)', fontsize=12)

# Format y-axis in millions
max_budget = merged_df['Average_Budget'].max()
y_ticks = range(0, int(max_budget + 25_000_000), 50_000_000)
plt.yticks(y_ticks, [f'${x/1e6:.1f}M' for x in y_ticks])

plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-4-87ebaa305922>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crime_df[year] = crime_df[year].replace({',': ''}, regex=True).astype(float)
# <ipython-input-4-87ebaa305922>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crime_df[year] = crime_df[year].replace({',': ''}, regex=True).astype(float)
# <ipython-input-4-87ebaa305922>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crime_df[year] = crime_df[year].replace({',': ''}, regex=True).astype(float)
# <ipython-input-4-87ebaa305922>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crime_df['Average_Crime'] = crime_df[['2020', '2021', '2022']].mean(axis=1)

# %% [markdown]
# **Interpretation:** This scatter plot displays the relationship between the average number of crimes and the average police budget across New Jersey counties from 2020 to 2022. Each point represents a county, labeled for clarity. Counties like Bergen and Essex have both high crime rates and high police budgets, reflecting larger urban populations. In contrast, counties such as Hunterdon and Sussex show lower crime numbers and receive significantly smaller budgets. There appears to be a general positive correlation—higher crime tends to be associated with higher police funding. However, some counties, like Passaic, have a relatively high budget despite moderate crime levels, suggesting other influencing factors. Smaller counties like Salem show low crime and budget levels, consistent with their size. The clustering of most counties in the lower-left quadrant suggests many regions have moderate to low crime and budget figures. Overall, the chart provides a helpful overview of how public safety funding aligns with crime trends in New Jersey.

# %% [markdown]
# #**Interactive Scatterplot of Average Crime vs Average Population 2020 - 2022**

# %%
import pandas as pd
import plotly.express as px

# URLs
url_crime_data = 'https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/crime%20by%20county%20New%20Jersey.csv'
url_population_data = 'https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/population%20by%20county.csv'

# Load and clean crime data
crime_data = pd.read_csv(url_crime_data, header=1)
crime_data = crime_data[crime_data['County'] != 'Total New Jersey']
for year in ['2020', '2021', '2022']:
    crime_data[year] = crime_data[year].str.replace(',', '', regex=True).astype(float)
crime_data['Average Crime'] = crime_data[['2020', '2021', '2022']].mean(axis=1)

# Standardize county names
crime_data['County'] = crime_data['County'].str.strip().str.lower()

# Load and clean population data
population_data = pd.read_csv(url_population_data)
population_data.columns = ['County', '2020', '2021', '2022']
for year in ['2020', '2021', '2022']:
    population_data[year] = population_data[year].str.replace(',', '', regex=True).astype(float)
population_data['Average Population'] = population_data[['2020', '2021', '2022']].mean(axis=1)

# Standardize county names
population_data['County'] = population_data['County'].str.strip().str.lower()

# Merge crime and population data (ensure all counties are included)
merged_data = pd.merge(crime_data[['County', 'Average Crime']],
                       population_data[['County', 'Average Population']],
                       on='County',
                       how='inner')  # only matching counties (all 21 should match now)

# Capitalize county names for display
merged_data['County'] = merged_data['County'].str.title()

# Create the interactive scatter plot
fig = px.scatter(
    merged_data,
    x='Average Crime',
    y='Average Population',
    color='County',
    hover_data=['County', 'Average Crime', 'Average Population'],
    labels={
        'Average Crime': 'Average Crime (2020–2022)',
        'Average Population': 'Average Population (2020–2022)'
    },
    title='Average Crime vs. Average Population (2020–2022) by County'
)

# Customize the plot
fig.update_traces(marker=dict(size=12, opacity=0.8, line=dict(width=1, color='black')))
fig.update_layout(showlegend=False)  # Hide legend to avoid clutter

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ffc34e53-8770-4af8-b72c-fb5ed7ee88e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffc34e53-8770-4af8-b72c-fb5ed7ee88e4")) {                    Plotly.newPlot(                        "ffc34e53-8770-4af8-b72c-fb5ed7ee88e4",                        [{"customdata":[["Atlantic"]],"hovertemplate":"County=%{customdata[0]}\u003cbr\u003eAverage Crime (2020–2022)=%{x}\u003cbr\u003eAverage Population (2020–2022)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Atlantic","marker":{"color":"#636efa","symbol":"circle","line":{"color":"black","width":1},"opacity":0.8,"size":12},"mode":"markers","name":"Atlantic","orientation":"v","showlegend":true,"x":[45315.666666666664],"xaxis":"x","y":[274842.6666666667],"yaxis":"y","type":"scatter"},{"customdata":[["Bergen"]],"hovertemplate":"County=%{customdata[0]}\u003cbr\u003eAverage Crime (2020–2022)=%{x}\u003cbr\u003eAverage Population (2020–2022)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bergen","marker":{"color":"#EF553B","symbol":"circle","line":{"color":"black","width":1},"opacity":0.8,"size":12},"mode":"markers","name":"Bergen","orientation":"v","showlegend":true,"x":[232254.0],"xaxis":"x","y":[954204.3333333334],"yaxis":"y","type":"scatter"},{"customdata":[["Burlington"]],"hovertemplate":"County=%{customdata[0]}\u003cbr\u003eAverage Crime (2020–2022)=%{x}\u003cbr\u003eAverage Population (2020–2022)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Burlington","marker":{"color":"#00cc96","symbol":"circle","line":{"color":"black","width":1},"opacity":0.8,"size":12},"mode":"markers","name":"Burlington","orientation":"v","showlegend":true,"x":[48680.666666666664],"xaxis":"x","y":[464087.3333333333],"yaxis":"y","type":"scatter"},{"customdata":[["Camden"]],"hovertemplate":"County=%{customdata[0]}\u003cbr\u003eAverage Crime (2020–2022)=%{x}\u003cbr\u003eAverage Population (2020–2022)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Camden","marker":{"color":"#ab63fa","symbol":"circle","line":{"color":"black","width":1},"opacity":0.8,"size":12},"mode":"markers","name":"Camden","orientation":"v","showlegend":true,"x":[137684.33333333334],"xaxis":"x","y":[523954.6666666667],"yaxis":"y","type":"scatter"},{"customdata":[["Cape May"]],"hovertemplate":"County=%{customdata[0]}\u003cbr\u003eAverage Crime (2020–2022)=%{x}\u003cbr\u003eAverage Population (2020–2022)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cape May","marker":{"color":"#FFA15A","symbol":"circle","line":{"color":"black","width":1},"opacity":0.8,"size":12},"mode":"markers","name":"Cape May","orientation":"v","showlegend":true,"x":[61871.0],"xaxis":"x","y":[95385.0],"yaxis":"y","type":"scatter"},{"customdata":[["Cumberland"]],"hovertemplate":"County=%{customdata[0]}\u003cbr\u003eAverage Crime (2020–2022)=%{x}\u003cbr\u003eAverage Population (2020–2022)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cumberland","marker":{"color":"#19d3f3","symbol":"circle","line":{"color":"black","width":1},"opacity":0.8,"size":12},"mode":"markers","name":"Cumberland","orientation":"v","showlegend":true,"x":[16675.666666666668],"xaxis":"x","y":[152383.0],"yaxis":"y","type":"scatter"},{"customdata":[["Essex"]],"hovertemplate":"County=%{customdata[0]}\u003cbr\u003eAverage Crime (2020–2022)=%{x}\u003cbr\u003eAverage Population (2020–2022)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Essex","marker":{"color":"#FF6692","symbol":"circle","line":{"color":"black","width":1},"opacity":0.8,"size":12},"mode":"markers","name":"Essex","orientation":"v","showlegend":true,"x":[49799.0],"xaxis":"x","y":[854643.6666666666],"yaxis":"y","type":"scatter"},{"customdata":[[" ...

# %% [markdown]
# **Interpretation:** This interactive scatter plot compares the average number of reported crimes to the average population in New Jersey counties from 2020 to 2022. Each point represents one of the 21 counties, ensuring full data coverage. Counties like Essex, Bergen, and Middlesex are located toward the top-right, showing both large populations and high crime counts. Less populated counties such as Salem, Hunterdon, and Sussex fall toward the bottom-left with lower values for both metrics. A visible positive correlation suggests that more populated areas tend to report more crimes overall. However, differences between counties with similar populations point to local factors that may influence crime rates. The use of hover labels allows for quick identification of each county’s stats. The plot is useful for identifying outliers, such as counties with higher crime levels relative to their population size. Overall, it provides a clear visual snapshot of how crime scales with population across the state.

# %% [markdown]
# #**Average Unemployment rates trend 2020 - 2022**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the updated unemployment data
url_unemployment = 'https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/unemployment%20rate%20by%20county.csv'
unemployment_data = pd.read_csv(url_unemployment)

# Clean up column names and values
unemployment_data.columns = unemployment_data.columns.str.strip()
unemployment_data['County'] = unemployment_data['County'].str.strip()

# Convert the columns for years to numeric values
unemployment_data['2020'] = pd.to_numeric(unemployment_data['2020'], errors='coerce')
unemployment_data['2021'] = pd.to_numeric(unemployment_data['2021'], errors='coerce')
unemployment_data['2022'] = pd.to_numeric(unemployment_data['2022'], errors='coerce')

# Compute the averages for each year
average_2020 = unemployment_data['2020'].mean()
average_2021 = unemployment_data['2021'].mean()
average_2022 = unemployment_data['2022'].mean()

# Data for the plot
years = ['2020', '2021', '2022']
averages = [average_2020, average_2021, average_2022]

# Start plotting the horizontal bar chart
fig, ax = plt.subplots(figsize=(8, 5))

# Plot horizontal bars for the unemployment data
colors = ['skyblue' for _ in averages]
bars = ax.barh(years, averages, color=colors, edgecolor='black')

# Add labels to the bars
for i, avg in enumerate(averages):
    ax.text(avg + 0.1, i, f'{avg:.1f}%', va='center')

# Axis labels and title
ax.set_xlabel('Average Unemployment Rate (%)')
ax.set_title('Average Unemployment Rate by Year in New Jersey')
ax.set_xlim(0, max(averages) + 2)
ax.invert_yaxis()  # Puts 2020 at the top
ax.grid(axis='x', linestyle='--', alpha=0.6)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation:**This bar chart shows the average unemployment rates in New Jersey for the years 2020, 2021, and 2022. The X-axis represents the average unemployment rate percentage, while the Y-axis lists the years. From the chart, it’s clear that the unemployment rate was highest in 2020, peaking during the early stages of the COVID-19 pandemic. The rate decreased in 2021 and continued to decline into 2022, reflecting recovery trends as the economy gradually improved. The bars provide a visual representation of how unemployment rates have decreased year-over-year. The chart highlights the impact of the pandemic on unemployment, followed by a gradual recovery. The differences between years show how effectively the state of New Jersey was able to reduce unemployment over the span of three years. This provides insight into the broader economic recovery in the region.

# %% [markdown]
# #**5 top dangerous cities**

# %%
# Load the data
crime_data = pd.read_csv(url_crime_data, header=1)
population_data = pd.read_csv(url_population_data)
unemployment_data = pd.read_csv(url_unemployment_data)

# Clean the crime data
crime_data = crime_data[crime_data['County'] != 'Total New Jersey']
for year in ['2020', '2021', '2022']:
    crime_data[year] = crime_data[year].str.replace(',', '', regex=True).astype(float)
crime_data['Average Crime'] = crime_data[['2020', '2021', '2022']].mean(axis=1)

# Clean the unemployment data
unemployment_data = unemployment_data[unemployment_data['County'] != 'Total New Jersey']
for year in ['2020', '2021', '2022']:
    # Convert to numeric directly (no need for str.replace)
    unemployment_data[year] = pd.to_numeric(unemployment_data[year], errors='coerce')
unemployment_data['Average Unemployment Rate'] = unemployment_data[['2020', '2021', '2022']].mean(axis=1)

# Merge the data
merged_data = pd.merge(crime_data[['County', 'Average Crime']],
                       unemployment_data[['County', 'Average Unemployment Rate']],
                       on='County')

# Sort by crime rate and get the top 5 most dangerous cities
top_5_dangerous_cities = merged_data.sort_values(by='Average Crime', ascending=False).head(5)

# Create the subplots
fig, ax = plt.subplots(1, 2, figsize=(14, 8))

# Plot Average Crime
ax[0].barh(top_5_dangerous_cities['County'], top_5_dangerous_cities['Average Crime'], color='red')
ax[0].set_xlabel('Average Crime (2020–2022)')
ax[0].set_title('Top 5 Most Dangerous Cities by Average Crime')

# Plot Average Unemployment Rate
ax[1].barh(top_5_dangerous_cities['County'], top_5_dangerous_cities['Average Unemployment Rate'], color='blue')
ax[1].set_xlabel('Average Unemployment Rate (2020–2022)')
ax[1].set_title('Top 5 Cities by Average Unemployment Rate')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-12-76dfbf9c7e56>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-12-76dfbf9c7e56>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-12-76dfbf9c7e56>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-12-76dfbf9c7e56>:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# **Interpretation:** The bar chart subplot visually compares the top 5 most dangerous cities in New Jersey based on average crime rates (2020-2022) and their corresponding average unemployment rates over the same period. In the first subplot, the cities with the highest average crime rates are highlighted, with red bars indicating the magnitude of crime in each county. The second subplot shows the relationship between the unemployment rate and crime, with blue bars representing the average unemployment rate for the same cities. The chart suggests that areas with higher crime rates may have varying unemployment rates, though the exact correlation is not directly analyzed. By visualizing these two datasets side by side, the comparison allows for insights into potential connections between crime and unemployment in New Jersey's most affected counties. Overall, the chart provides a clear and impactful way to understand how these social issues overlap in specific regions.

# %% [markdown]
# #**Heatmap with variables**

# %%
# Load the data
crime_data = pd.read_csv(url_crime_data, header=1)
budget_data = pd.read_csv(url_budget_data, header=1)
population_data = pd.read_csv(url_population_data)
unemployment_data = pd.read_csv(url_unemployment)

# Clean column names
population_data.columns = population_data.columns.str.strip()
crime_data['County'] = crime_data['County'].str.strip()
budget_data['County'] = budget_data['County'].str.strip()
population_data['County'] = population_data['County'].str.strip()
unemployment_data['County'] = unemployment_data['County'].str.strip()

# Clean and convert population columns
population_data['2,020'] = population_data['2,020'].replace({',': ''}, regex=True).astype(int)
population_data['2,021'] = population_data['2,021'].replace({',': ''}, regex=True).astype(int)
population_data['2,022'] = population_data['2,022'].replace({',': ''}, regex=True).astype(int)
population_data['Population'] = population_data[['2,020', '2,021', '2,022']].mean(axis=1)

# Clean and convert crime columns
crime_data['2020'] = crime_data['2020'].replace({',': ''}, regex=True).astype(int)
crime_data['2021'] = crime_data['2021'].replace({',': ''}, regex=True).astype(int)
crime_data['2022'] = crime_data['2022'].replace({',': ''}, regex=True).astype(int)
crime_data['Total Crime'] = crime_data['2020'] + crime_data['2021'] + crime_data['2022']

# Clean and convert budget columns
budget_data['2020'] = budget_data['2020'].replace({',': ''}, regex=True).astype(float)
budget_data['2021'] = budget_data['2021'].replace({',': ''}, regex=True).astype(float)
budget_data['2022'] = budget_data['2022'].replace({',': ''}, regex=True).astype(float)
budget_data['Total Budget'] = budget_data['2020'] + budget_data['2021'] + budget_data['2022']

# Average unemployment rate (2020–2022)
unemployment_data['Unemployment Rate'] = unemployment_data[['2020', '2021', '2022']].mean(axis=1)

# Merge all datasets
merged_data = pd.merge(crime_data[['County', 'Total Crime']], budget_data[['County', 'Total Budget']], on='County')
merged_data = pd.merge(merged_data, population_data[['County', 'Population']], on='County')
merged_data = pd.merge(merged_data, unemployment_data[['County', 'Unemployment Rate']], on='County')

# Correlation matrix
correlation_matrix = merged_data[['Total Crime', 'Total Budget', 'Population', 'Unemployment Rate']].corr()

# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", cbar=True)
plt.title('Correlation Heatmap: Crime, Budget, Population, and Unemployment Rate', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Analysis:** This analysis supports the hypothesis that higher crime rates are associated with larger police budgets. The moderate positive correlation (0.59) between Total Crime and Total Budget suggests that counties experiencing more crime tend to allocate more resources to law enforcement. Likewise, the correlation between crime and population (0.55) highlights that densely populated areas often face more incidents, naturally demanding higher public safety spending. However, the near-zero correlation (0.05) between crime and unemployment challenges common assumptions about economic hardship driving crime. Surprisingly, unemployment also lacks significant correlation with police budgets (-0.02), suggesting that fiscal decisions are not directly driven by joblessness. The strong link between population and budget (0.96) reflects logical resource allocation based on community size. Overall, the findings indicate that population size and crime levels are stronger predictors of police funding than socioeconomic distress. These patterns offer insights into how New Jersey counties prioritize public safety during times of change. They also reinforce that public perception and crime data—not necessarily economic strain—may shape policy responses.

# %% [markdown]
# #**Budget per capita 2020 to 2022**

# %%
import plotly.graph_objects as go
# Load CSVs
crime_data = pd.read_csv(url_crime_data, header=1)
budget_data = pd.read_csv(url_budget_data, header=1)
population_data = pd.read_csv(url_population_data)

# Clean County column
for df in [crime_data, budget_data, population_data]:
    df['County'] = df['County'].str.strip()

# Convert numeric columns
for year in ['2020', '2021', '2022']:
    budget_data[year] = budget_data[year].replace({',': ''}, regex=True).astype(float)

# Compute total budget
budget_data['Total Budget'] = budget_data[['2020', '2021', '2022']].sum(axis=1)

# Clean and average population
population_data['2,020'] = population_data['2,020'].replace({',': ''}, regex=True).astype(int)
population_data['2,021'] = population_data['2,021'].replace({',': ''}, regex=True).astype(int)
population_data['2,022'] = population_data['2,022'].replace({',': ''}, regex=True).astype(int)
population_data['Population'] = population_data[['2,020', '2,021', '2,022']].mean(axis=1)

# Merge datasets
merged = budget_data[['County', 'Total Budget']].merge(
    population_data[['County', 'Population']], on='County'
)

# Compute budget per capita
merged['Budget per Capita'] = merged['Total Budget'] / merged['Population']

# Sort for better visualization
merged.sort_values(by='Budget per Capita', ascending=False, inplace=True)

# Create figure for budget per capita only
fig = go.Figure()

# Add Budget per Capita bars (in blue)
fig.add_trace(go.Bar(
    x=merged['County'],
    y=merged['Budget per Capita'],
    name='Budget per Capita',
    marker_color='blue',
    text=merged['Budget per Capita'].round(2),
    textposition='outside',
    width=0.4
))

fig.update_layout(
    title='Police Budget per Capita by County (2020–2022)',
    xaxis=dict(
        title='County',
        tickangle=45,
        tickmode='array',
        tickvals=merged['County'],
    ),
    yaxis=dict(
        title='Budget per Capita (USD)',
        showgrid=False,
        tickformat=".2f"
    ),
    legend=dict(x=0.5, y=1.1, xanchor='center', orientation='h'),
    bargap=0.1,
    width=1000,
    height=700
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8f0e21dd-be3e-4d8d-a87c-5aaca82aff90" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f0e21dd-be3e-4d8d-a87c-5aaca82aff90")) {                    Plotly.newPlot(                        "8f0e21dd-be3e-4d8d-a87c-5aaca82aff90",                        [{"marker":{"color":"blue"},"name":"Budget per Capita","text":[1624.37,1412.09,1400.87,1364.86,1312.26,1265.97,1149.78,1080.24,1056.94,1019.2,863.77,811.2,804.1,802.43,771.6,747.1,712.9,699.78,688.3,666.29,582.78],"textposition":"outside","width":0.4,"x":["Cape May","Bergen","Essex","Hudson","Atlantic","Monmouth","Union","Morris","Ocean","Middlesex","Passaic","Burlington","Somerset","Camden","Mercer","Warren","Cumberland","Gloucester","Hunterdon","Sussex","Salem"],"y":[1624.3664896996384,1412.093648257728,1400.869214896969,1364.8647233078975,1312.256646990763,1265.9667481424362,1149.7762931545624,1080.2432651471536,1056.9351178706481,1019.1964584353694,863.7730724633208,811.198904451892,804.0957389827015,802.4319298743403,771.6009410422848,747.0950769509653,712.9021638240486,699.7810389617495,688.2954341398334,666.2873480679486,582.7761471572935],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay", ...

# %% [markdown]
# **Interpretation:** This bar chart displays the police budget per capita across New Jersey counties, averaged over the years 2020 to 2022. Each bar represents the total police budget divided by the average population for each county during that period. The chart helps highlight how much is being spent per person on policing in different regions. Some counties, such as Bergen and Essex, show significantly higher per capita spending, likely reflecting larger populations or more complex urban demands. In contrast, rural counties like Salem and Sussex have noticeably lower budget allocations per person. The visualization allows easy comparison of resource distribution and may raise questions about equity, efficiency, or need-based allocation. Policymakers could use this data to assess whether funding is aligned with population size or community safety needs. Overall, the chart emphasizes budget disparities and can support further investigation into public safety investment strategies.

# %% [markdown]
# #**Visualization of New Jersey Interactive Map**

# %%
import pandas as pd

# Cargar los datos de criminalidad desde el CSV
url_crime_data = 'https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/crime%20by%20county%20New%20Jersey.csv'
crime_data = pd.read_csv(url_crime_data, header=1)

# Limpiar los datos: eliminar comas y convertir a valores numéricos
for year in ['2020', '2021', '2022']:
    crime_data[year] = crime_data[year].str.replace(',', '').astype(float)

# Eliminar la fila de totales
crime_data = crime_data[crime_data['County'] != 'Total New Jersey']

# Calcular el promedio de crimen entre 2020 y 2022
crime_data['Average_2020_2022'] = crime_data[['2020', '2021', '2022']].mean(axis=1)

# Obtener los 5 condados con el promedio más alto
top5_avg_crime = crime_data.sort_values(by='Average_2020_2022', ascending=False).head(5)

# Mostrar resultado
print(top5_avg_crime[['County', 'Average_2020_2022']])
# Out:
#        County  Average_2020_2022
# 1     Bergen       232254.000000
# 3      Camden      137684.333333
# 12  Monmouth        77602.666667
# 4   Cape May        61871.000000
# 6       Essex       49799.000000

# %%
import geopandas as gpd
import pandas as pd
import folium
from folium.plugins import HeatMap

# Load the geospatial data for New Jersey counties from the GeoJSON file
url_geojson = 'https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/main/NJ_Counties_3424_-8325300193892812354%20(2).geojson'
gdf = gpd.read_file(url_geojson)

# Check the first values of the 'REGION' column to see if it contains the county names
print(gdf['REGION'].head())

# Rename the 'REGION' column to 'County' if it contains the county names
gdf = gdf.rename(columns={'REGION': 'County'})

# Load the crime and budget data
url_crime_data = 'https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/crime%20by%20county%20New%20Jersey.csv'
url_budget_data = 'https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/police%20budgets%20in%20New%20Jersey.csv'

crime_data = pd.read_csv(url_crime_data, header=1)
budget_data = pd.read_csv(url_budget_data, header=1)

# Clean the data (remove rows with null values)
crime_data = crime_data.dropna(subset=['2020', '2021', '2022'])
budget_data = budget_data.dropna(subset=['2020'])

# Calculate the total crime for each county over the 3 years (2020-2022)
crime_data['Total_Crime'] = crime_data['2020'] + crime_data['2021'] + crime_data['2022']

# Convert 'Total_Crime' to numeric (handling any non-numeric characters like commas)
crime_data['Total_Crime'] = pd.to_numeric(crime_data['Total_Crime'], errors='coerce')

# Rename columns for easier merging
crime_data = crime_data[['County', 'Total_Crime']]
budget_data = budget_data[['County', '2020']]  # You can also calculate the total budget for 2020-2022

# Rename the columns
budget_data.columns = ['County', 'Budget_2020']

# Merge the crime and budget data
merged_data = pd.merge(crime_data, budget_data, on='County', how='left')

# Merge the geospatial data with the crime and budget data
gdf = gdf.merge(merged_data, on='County')

# Identify the top 5 counties with the highest crime
top_5_counties = gdf.nlargest(5, 'Total_Crime')

# Create a map centered on New Jersey
m = folium.Map(location=[40.0583, -74.4057], zoom_start=8)

# Add the counties with the highest crime levels to the map
for _, row in top_5_counties.iterrows():
    folium.GeoJson(row['geometry'],
                   style_function=lambda x: {'fillColor': 'red', 'color': 'black', 'weight': 2, 'fillOpacity': 0.5}).add_to(m)

# Add a heatmap layer for the 'Crime_2020'
HeatMap(data=gdf[['geometry', 'Total_Crime']].dropna(), radius=15).add_to(m)

# Display the map
m
# Out:
# 0         COASTAL
# 1    NORTHEASTERN
# 2        SOUTHERN
# 3        SOUTHERN
# 4         COASTAL
# Name: REGION, dtype: object
# <ipython-input-47-359af3aae9ff>:58: FutureWarning:
#
# <class 'geopandas.array.GeometryArray'>._reduce will require a `keepdims` parameter in the future
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7c0817e13fda7612ea9a4ebc8229a42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7c0817e13fda7612ea9a4ebc8229a42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7c0817e13fda7612ea9a4ebc8229a42 = L.map(
#                 &quot;map_b7c0817e13fda7612ea9a4ebc8229a42&quot;,
#                 {
#                     center: [40.0583, -74.4057],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4fd72807ecaf0068e048cc17f473c9c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4fd72807ecaf0068e048cc17f473c9c7.addTo(map_b7c0817e13fda7612ea9a4ebc8229a42);
#
#
#             var heat_map_53a11589b06203febcbc8a21977b57fb = L.heatLayer(
#                 [],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 15,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_53a11589b06203febcbc8a21977b57fb.addTo(map_b7c0817e13fda7612ea9a4ebc8229a42);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #**Restate the Hypothesis and Results**

# %% [markdown]
# **Restate the Hypothesis and Results:**
#
# The initial hypothesis posited that higher unemployment rates would correlate with higher crime rates across New Jersey counties between 2020 and 2022. The data analysis explored this assumption by examining relationships between crime rates, unemployment rates, police budgets, and population size. The primary findings suggest that crime rates are more strongly correlated with population size and police budgets than with unemployment rates. Specifically, the correlation between crime rates and unemployment was found to be very weak, indicating that unemployment alone does not have a significant impact on crime rates in this context. On the other hand, there was a moderate to strong correlation between total crime and both police budgets and population size, suggesting that areas with higher population density and greater police funding tend to report higher crime rates.
#
# **Insights and Implications:**
#
# The findings suggest that the key drivers of crime in New Jersey counties are likely to be related to population size and the level of police funding rather than unemployment rates. The moderate correlation between crime and police budgets might imply that larger budgets are allocated in areas with higher crime rates, possibly reflecting increased demand for law enforcement resources in high-crime areas. However, this could also suggest that higher crime rates lead to larger budgets, rather than the budget causing crime. The weak correlation between unemployment and crime challenges the initial hypothesis and suggests that other socioeconomic factors, such as education or housing instability, might have a more direct impact on crime levels. These results call for a broader exploration of the social determinants of crime, beyond just unemployment, to understand the full range of factors that influence crime rates.
#
# The story told by the data is that crime rates are intricately linked to the resources allocated for law enforcement and the size of the community, which may be a reflection of larger social and demographic trends. While unemployment might not be a direct driver of crime, areas facing economic challenges and high levels of unemployment might still experience other social issues that contribute to higher crime rates. Future research could benefit from considering a wider range of variables—such as education, housing, and mental health services—to better understand the factors that truly influence crime beyond just economic conditions.

# %% [markdown]
# #**Conclusions and Limitations**

# %% [markdown]
# **Conclusions**
#
# After conducting the analysis of crime data in New Jersey counties from 2020 to 2022, several insights emerge that tie back to the hypothesis. The scatter plot and other visualizations reveal that while there is a noticeable variation in crime rates across counties, the relationship between crime rates and factors like police budgets and unemployment is not as straightforward as expected. Although it was hypothesized that higher unemployment rates would correlate with higher crime rates, the data did not show a strong relationship between these two variables. This suggests that other factors, such as population density or local law enforcement practices, may play a more significant role in determining crime rates.
#
# Furthermore, the analysis of crime rates across the top 5 counties with the highest total crime rates highlights that the years 2020 to 2022 saw significant variation in crime reporting. Counties like Passaic, Camden, and Essex reported some of the highest crime totals, which supports the idea that urbanized areas with larger populations tend to have higher crime rates. However, when comparing these figures with police budgets, it became clear that having a larger budget does not necessarily correlate with a reduction in crime, as some counties with high crime rates also had relatively large police budgets, challenging the assumption that more funding directly leads to lower crime.
#
# However, there are limitations to this analysis. First, the crime data used in this study does not account for variations in crime reporting methods or law enforcement strategies, which may differ between counties. Additionally, the dataset does not include specific factors such as socioeconomic conditions or educational levels, which could influence crime rates. Lastly, the analysis did not take into account the severity or types of crime, which can vary widely and may not be equally influenced by police budgets or unemployment. Future research could focus on exploring these factors and incorporating a wider range of variables to provide a more nuanced understanding of crime trends and the effectiveness of police funding.
#
# **Limitations and Future Research**
#
# While the analysis provided valuable insights into crime trends across New Jersey counties, several limitations should be considered. The dataset used in this study is based on aggregate crime numbers, which may mask important nuances such as the type of crimes committed or the distribution of crime across neighborhoods. Additionally, the absence of data on law enforcement effectiveness or community-level interventions limits the ability to draw definitive conclusions about the relationship between police budgets and crime. Future research could benefit from a more granular approach that includes not only total crime rates but also information on specific crime categories, demographic factors, and community outreach programs. Furthermore, the study could be expanded by integrating longitudinal data to better understand how crime trends evolve over time and whether specific interventions have had a measurable impact.

# %% [markdown]
# **References:** ChatGPT for coding
